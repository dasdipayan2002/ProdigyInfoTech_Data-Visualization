# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [raw]
# # Load the dataset
# data = pd.read_csv('population_data.csv')
#
# # Display the first few rows of the dataset
# data.head()

# %%
# Select relevant columns (adjust based on dataset structure)
selected_data = data[['Country Name', '2019']]
selected_data = selected_data.dropna()  # Remove missing values if any

# Display a summary of the selected data
selected_data.describe()
# Out:
#                2019
# count  2.650000e+02
# mean   3.138348e+08
# std    9.774204e+08
# min    1.095600e+04
# 25%    1.788878e+06
# 50%    1.044767e+07
# 75%    5.987258e+07
# max    7.742725e+09

# %%
# Bar chart: Top 10 countries by population in 2019
top_countries = selected_data.sort_values(by='2019', ascending=False).head(10)
plt.figure(figsize=(10, 6))
sns.barplot(data=top_countries, x='2019', y='Country Name', palette='viridis')
plt.title('Top 10 Countries by Population in 2019')
plt.xlabel('Population')
plt.ylabel('Country Name')
plt.tight_layout()
plt.show()

# %%
# Histogram: Distribution of population values in 2019
plt.figure(figsize=(10, 6))
sns.histplot(selected_data['2019'], bins=20, kde=True, color='blue')
plt.title('Distribution of Population in 2019')
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
